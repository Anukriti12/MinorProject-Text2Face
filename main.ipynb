# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !git clone https://github.com/Anukriti12/MajorProject.git
# Out:
# Cloning into 'MajorProject'...
# remote: Enumerating objects: 56, done.
# remote: Counting objects: 100% (56/56), done.
# remote: Compressing objects: 100% (44/44), done.
# remote: Total 56 (delta 6), reused 51 (delta 4), pack-reused 0
# Unpacking objects: 100% (56/56), done.

# %%
# %tensorflow_version 1.x
import tensorflow.compat.v1 as tf
# Out:
# TensorFlow 1.x selected.

# %%
tf.__version__
# Out:
# '1.15.2'

# %%
# !pip3 install prettytensor
# Out:
# ...
#      |████████████████████████████████| 276kB 7.9MB/s
# ...

# %%
import prettytensor as pt
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/prettytensor/bookkeeper.py:43: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/prettytensor/pretty_tensor_methods.py:705: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/prettytensor/local_trainer.py:37: The name tf.train.SessionManager is deprecated. Please use tf.compat.v1.train.SessionManager instead.

# %%
# %cd MajorProject
# Out:
# /content/MajorProject

# %%
# !pwd
# Out:
# /content/MajorProject

# %%
# replace misc/datasets.py , misc/config.py from desktop

# %%
# !unrar x "Data/birds/test/76images.rar" "Data/birds/test" 
# !unrar x "Data/birds/train/filenames.rar" "Data/birds/train" 
# !unrar x "Data/birds/train/class_info.rar" "Data/birds/train"
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Data/birds/test/76images.rar
#
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Data/birds/train/filenames.rar
#
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from Data/birds/train/class_info.rar
#
#   OK
# All OK

# %%
# For test data:
# !unrar x "/content/gdrive/My Drive/minor/char-CNN-RNN-embeddings.rar" "Data/birds/test" 
# !unrar x "/content/gdrive/My Drive/minor/class_info.rar" "Data/birds/test" 
# !unrar x "/content/gdrive/My Drive/minor/filenames.rar" "Data/birds/test" 
# !unrar x "/content/gdrive/My Drive/minor/304images.rar" "Data/birds/test"
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/gdrive/My Drive/minor/char-CNN-RNN-embeddings.rar
#
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/gdrive/My Drive/minor/class_info.rar
#
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/gdrive/My Drive/minor/filenames.rar
#
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/gdrive/My Drive/minor/304images.rar
#
#   OK
# All OK

# %%
# For train data:
# !unrar x "/content/gdrive/My Drive/minor/train/class_info.rar" "Data/birds/train" 
# !unrar x "/content/gdrive/My Drive/minor/train/filenames.rar" "Data/birds/train" 
# !unrar x "/content/gdrive/My Drive/minor/train/76images.rar" "Data/birds/train" 
# !unrar x "/content/gdrive/My Drive/minor/train/char-CNN-RNN-embeddings.rar" "Data/birds/train" 
#!unrar x "/content/gdrive/My Drive/minor/train/304images.rar" "Data/birds/train"
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/gdrive/My Drive/minor/train/76images.rar
#
#   OK
# All OK
#
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/gdrive/My Drive/minor/train/char-CNN-RNN-embeddings.rar
#
#   OK
# All OK

# %%
# !python stageI/run_exp.py --cfg stageI/cfg/birds.yml --gpu 0
# Out:
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/compat/v2_compat.py:68: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/prettytensor/bookkeeper.py:43: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/prettytensor/pretty_tensor_methods.py:705: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/prettytensor/local_trainer.py:37: The name tf.train.SessionManager is deprecated. Please use tf.compat.v1.train.SessionManager instead.
#
# Using config:
# {'CONFIG_NAME': 'stageI',
#  'DATASET_NAME': 'birds',
#  'EMBEDDING_TYPE': 'cnn-rnn',
#  'GAN': {'DF_DIM': 64,
# ...

# %%
# !cat '/usr/local/lib/python3.6/dist-packages/prettytensor/scopes.py'
# Out:
# # Copyright 2015 Google Inc. All Rights Reserved.
# # Licensed under the Apache License, Version 2.0 (the "License");
# # you may not use this file except in compliance with the License.
# # You may obtain a copy of the License at
# #     http://www.apache.org/licenses/LICENSE-2.0
# # Unless required by applicable law or agreed to in writing, software
# # distributed under the License is distributed on an "AS IS" BASIS,
# # WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# # See the License for the specific language governing permissions and
# # limitations under the License.
# """Contains methods related to making templates."""
# from __future__ import absolute_import
# from __future__ import division
# from __future__ import print_function
#
# import contextlib
# import functools
# import traceback
#
# from six.moves import zip  # pylint: disable=redefined-builtin
# import tensorflow as tf
#
# from tensorflow.python.ops import variable_scope
#
#
# ...

# %%
# !git clone https://github.com/hanzhanggit/StackGAN-v2.git
# Out:
# Cloning into 'StackGAN-v2'...
# remote: Enumerating objects: 96, done.
# remote: Total 96 (delta 0), reused 0 (delta 0), pack-reused 96
# Unpacking objects: 100% (96/96), done.

# %%
# %tensorflow_version 1.x
import tensorflow.compat.v1 as tf
# Out:
# TensorFlow 1.x selected.

# %%
# !ls /content/gdrive/MyDrive/minor
# Out:
# 304images.rar  char-CNN-RNN-embeddings.rar  CUB_200_2011.rar  train
# birds.rar      class_info.rar		    filenames.rar     Untitled0.ipynb

# %%
# !unrar x "/content/gdrive/MyDrive/minor/birds.rar" "StackGAN-v2/data"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    StackGAN-v2/data/birds/text_c10/119.Field_Sparrow         OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    StackGAN-v2/data/birds/text_c10/120.Fox_Sparrow           OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !unrar x "/content/gdrive/MyDrive/minor/CUB_200_2011.rar" "StackGAN-v2/data/birds"
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    StackGAN-v2/data/birds/CUB_200_2011/images/119.Field_Sparrow  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    StackGAN-v2/data/birds/CUB_200_2011/images/120.Fox_Sparrow  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# %cd StackGAN-v2/code
# Out:
# /content/StackGAN-v2/code

# %%
#!pip3 install tensorboardX
# !pip3 install tensorboard-pytorch

# %%
# !pip3 install tensorboard-pytorch
# Out:
# ...
#      |████████████████████████████████| 81kB 7.8MB/s
# ...

# %%
# tensorboard-pytorch.__version__

# %%
# !pip3 install tensorboard==1.15.0

# %%
# !pip3 install torch
# !pip3 install torchvision
# !pip3 install tensorboard==1.11.0
# !pip3 install tensorboardX==1.1

# %%
# !pip3 install tensorboard-pytorch==0.7.1
#  (from versions: 0.1, 0.2, 0.3, 0.4, 0.6, 0.6.5, 0.7, 0.7.1)

# %%
# code/miscc/config.py code/trainer.py  miscc/datasets.py
# Rename data/birds/text_c2.0 to text only

# %%
# !python3 main.py --cfg cfg/birds_3stages.yml --gpu 0
# Out:
# Using config:
# {'CONFIG_NAME': '3stages',
#  'CUDA': True,
#  'DATASET_NAME': 'birds',
#  'DATA_DIR': '../data/birds',
#  'EMBEDDING_TYPE': 'cnn-rnn',
#  'GAN': {'B_CONDITION': True,
#          'DF_DIM': 64,
#          'EMBEDDING_DIM': 128,
#          'GF_DIM': 64,
#          'NETWORK_TYPE': 'default',
#          'R_NUM': 2,
#          'Z_DIM': 100},
#  'GPU_ID': '0',
#  'TEST': {'B_EXAMPLE': True, 'SAMPLE_NUM': 30000},
#  'TEXT': {'DIMENSION': 1024},
#  'TRAIN': {'BATCH_SIZE': 24,
#            'COEFF': {'COLOR_LOSS': 0.0, 'KL': 2.0, 'UNCOND_LOSS': 1.0},
#            'DISCRIMINATOR_LR': 0.0002,
#            'FLAG': True,
#            'GENERATOR_LR': 0.0002,
#            'MAX_EPOCH': 600,
#            'NET_D': '',
#            'NET_G': '',
#            'SNAPSHOT_INTERVAL': 2000,
#            'VIS_COUNT': 64},
#  'TREE': {'BASE_SIZE': 64, 'BRANCH_NUM': 3},
#  'WORKERS': 4}
# ...

# %%
# !zip -r /content/gdrive/MyDrive/minor/file1.zip /content/StackGAN-v2/output
# Out:
# 	zip warning: name not matched: /content/StackGAN-v2/output
#
# zip error: Nothing to do! (try: zip -r /content/file1.zip . -i /content/StackGAN-v2/output)

# %%
# !ls
# Out:
# sample_data

# %%
from google.colab import files
files.download("/content/file1.zip")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-03ecbd7f1a9a> in <module>()
#       1 from google.colab import files
# ----> 2 files.download("/content/file1.zip")
#
# /usr/local/lib/python3.6/dist-packages/google/colab/files.py in download(filename)
#     141       raise OSError(msg)
#     142     else:
# --> 143       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     144
#     145   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: /content/file1.zip
